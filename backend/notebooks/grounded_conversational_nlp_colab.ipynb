# %% [markdown]
# # Grounded Conversational NLP Colab
#
# This notebook mounts Google Drive, clones the repo, installs backend dependencies, and runs one script to build the `umat_nlp_project` grounded conversational pipeline.

# %%
from google.colab import drive
drive.mount('/content/drive')

PROJECT_ROOT = '/content/drive/MyDrive/umat_nlp_project'
RAW_DIR = f'{PROJECT_ROOT}/data/raw'
PROCESSED_DIR = f'{PROJECT_ROOT}/data/processed'
SYNTHETIC_DIR = f'{PROJECT_ROOT}/data/synthetic'
METRICS_DIR = f'{PROJECT_ROOT}/metrics'
REPO_DIR = '/content/NLP_Project'

# %%
# !rm -rf "$REPO_DIR"
# !git clone https://github.com/Kevin-nav/UMaT-Grounded-Conversational-NLP-Assistant.git "$REPO_DIR"
# %cd /content/NLP_Project/backend
# !python -m pip install --upgrade pip
# !python -m pip install -e .

# %%
from app.ml.synthetic_data import generate_synthetic_dialogues
from app.ml.train_retriever import run_retriever_training
from app.ml.train_generator import run_generator_training
from app.ml.eval_generator import evaluate_generator_outputs

# The single command below executes the full export, training, and evaluation flow.
# !python -m scripts.run_full_ml_pipeline --output-root "$PROJECT_ROOT"
